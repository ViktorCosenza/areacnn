# %%
from PIL import Image, ImageDraw
import numpy as np

# %%
im = Image.fromarray(    
    np.random.normal(127, 127, size=(512, 512, 3)).astype(np.uint8)
)
draw = ImageDraw.ImageDraw(im)
draw.rectangle((25, 25, 250, 250), fill=(255, 0, 0), outline=(0, 255, 0))
im
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FF531A595C0>

# %%
np.random.normal()
# Out:
# -1.4903800705173158
